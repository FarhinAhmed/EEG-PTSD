# %%
import time
import bluetooth
from mindwavemobile.MindwaveDataPoints import RawDataPoint
from mindwavemobile.MindwaveDataPoints import *
from mindwavemobile.MindwaveDataPointReader import MindwaveDataPointReader
import textwrap
import pandas as pd
from datetime import datetime
import os.path

# %%
eeg_df = None
limit_of_data_taken  = 500
limit_of_ignore = 120
user_id = 0
user_activity_id = 3
user_mental_state_id = 2

# %%
def collect_data(user_id,user_activity_id,user_mental_state_id,session_id):
    
    mindwaveDataPointReader = MindwaveDataPointReader()
    mindwaveDataPointReader.start()
    all_rows = []
    if (mindwaveDataPointReader.isConnected()):    
        count = 0
        att = False
        med = False
        eeg = False
        
        current_row = {}
        count_ignore = 0
        while(True):
            
            if(count > limit_of_data_taken):
                break
            
            dataPoint = mindwaveDataPointReader.readNextDataPoint()
            
            if(count_ignore < limit_of_ignore):
                count_ignore += 1
                continue
            
            if (dataPoint.__class__ is RawDataPoint and dataPoint.__class__ is PoorSignalLevelDataPoint):
                continue
            elif(dataPoint.__class__ is AttentionDataPoint):
                if(att == False):
                    att = True
                    current_row['attention'] = dataPoint.attentionValue
                    #print(current_row['attention'])
            
            elif(dataPoint.__class__ is MeditationDataPoint):
                if(med == False):
                    current_row['meditation'] = dataPoint.meditationValue
                    #print(current_row['meditation'])
                    med = True
            elif(dataPoint.__class__ is EEGPowersDataPoint):
                if(eeg == False):
                    current_row['delta'] = dataPoint.delta
                    current_row['theta'] = dataPoint.theta
                    current_row['lowAlpha'] = dataPoint.lowAlpha
                    current_row['highAlpha'] = dataPoint.highAlpha
                    current_row['lowBeta'] = dataPoint.lowBeta
                    current_row['highBeta'] = dataPoint.highBeta
                    current_row['lowGamma'] = dataPoint.lowGamma
                    current_row['midGamma'] = dataPoint.midGamma
                    eeg = True
            
            if(att == True and med == True and eeg == True):
                att = False
                med = False
                eeg = False
                count += 1
                
                if(count % 10 == 0):
                    print("iteration: ",count)
                    
                current_row['recording_time'] = datetime.now()
                current_row['user_id'] = user_id
                current_row['user_activity_id'] = user_activity_id
                current_row['user_mental_state_id'] = user_mental_state_id
                current_row['session_id'] = session_id
                
                all_rows.append(current_row)
                #print(current_row)
                current_row = {}
       
                
    else:
        print(textwrap.dedent("""\
            Exiting because the program could not connect
            to the Mindwave Mobile device.""").replace("\n", " "))
                            
            
    #print(all_rows)
    return all_rows

# %%
def reload_eeg_dataframe():
    #first, we will check whether there exists a file named eeg_dataset.csv file. If there is, then it will be loaded as df.
    #Otherwise, it will be created brand new.
    if(os.path.exists("eeg_dataset")):
        print("file exists")
  
        eeg_df = pd.read_csv("eeg_dataset",parse_dates = True)
        eeg_df['recording_time'] = eeg_df['recording_time'].astype("datetime64[ms]")
        session_id = eeg_df.iloc[-1]['session_id'] + 1
    else:
        print("file does not exist")
        eeg_df = pd.DataFrame(columns=['user_id','user_activity_id','user_mental_state_id','attention','meditation','delta','theta','lowAlpha','highAlpha','lowBeta','highBeta','lowGamma','midGamma','recording_time','session_id'])
        for cur_col in eeg_df.columns:

            if(cur_col == 'recording_time'):
                eeg_df[cur_col] = eeg_df[cur_col].astype("datetime64[ms]")
            elif(cur_col == 'user_activity_id' or cur_col=='user_id' or cur_col == 'user_mental_state_id' or cur_col == 'session_id' ):
                eeg_df[cur_col] = eeg_df[cur_col].astype("int") 
            else:
                eeg_df[cur_col] = eeg_df[cur_col].astype("float32") 
        session_id = 0
    return eeg_df,session_id

# %%
eeg_df,session_id = reload_eeg_dataframe()

all_rows = collect_data(user_id,user_activity_id,user_mental_state_id,session_id)
temp_df = pd.DataFrame(all_rows)
eeg_df = eeg_df.append([temp_df])
#eeg_df.dtypes
eeg_df.to_csv("eeg_dataset", encoding='utf-8', index=False)
# Out:
# file exists
# Discovered Mindwave Mobile...
# iteration:  10
# iteration:  20
# iteration:  30
# iteration:  40
# iteration:  50
# iteration:  60
# iteration:  70
# iteration:  80
# iteration:  90
# iteration:  100
# iteration:  110
# iteration:  120
# iteration:  130
# iteration:  140
# iteration:  150
# iteration:  160
# iteration:  170
# iteration:  180
# iteration:  190
# iteration:  200
# iteration:  210
# iteration:  220
# iteration:  230
# iteration:  240
# iteration:  250
# iteration:  260
# iteration:  270
# iteration:  280
# iteration:  290
# iteration:  300
# iteration:  310
# iteration:  320
# iteration:  330
# iteration:  340
# iteration:  350
# iteration:  360
# iteration:  370
# iteration:  380
# iteration:  390
# iteration:  400
# iteration:  410
# iteration:  420
# iteration:  430
# iteration:  440
# iteration:  450
# iteration:  460
# iteration:  470
# iteration:  480
# iteration:  490
# iteration:  500

# %%
eeg_df
# Out:
#      attention      delta  highAlpha  highBeta  lowAlpha   lowBeta  lowGamma  \
# 0          0.0       58.0        0.0       1.0       1.0       1.0       0.0
# 1          0.0    67471.0     1081.0     474.0    1358.0     754.0     403.0
# 2          0.0   310378.0     7363.0    3339.0   15885.0    6697.0    1267.0
# 3          0.0  1344528.0    41591.0    8741.0   19419.0   16919.0    2041.0
# 4          0.0   521855.0    46372.0    9626.0   28008.0   25506.0    3433.0
# 5         51.0   367356.0    17759.0   10064.0   30463.0   10849.0    2447.0
# 6         69.0   553855.0    14216.0   17022.0   65367.0   21597.0    2295.0
# 7         84.0    25994.0     1433.0     330.0     186.0    1114.0     139.0
# 8         96.0   967449.0    39754.0   15440.0   45143.0   24030.0   19586.0
# 9         96.0    55856.0     3515.0    1324.0    1562.0    2484.0     185.0
# 10        63.0   844922.0    49654.0    9348.0  112433.0   21791.0    4182.0
# 11        50.0   798133.0    18129.0    7389.0   46964.0   18292.0    1298.0
# 12        34.0    27997.0     1143.0    1479.0    5085.0    1415.0     347.0
# 13        43.0   232934.0     3813.0    7721.0    5624.0    1755.0     674.0
# 14        56.0    47585.0     2423.0     433.0    1002.0     886.0      93.0
# 15        70.0   864842.0    20465.0   10329.0    6693.0   11104.0    1440.0
# 16        78.0   248484.0     4996.0     862.0    5743.0    8373.0     587.0
# 17        56.0   885404.0    19448.0    3388.0   16378.0   14013.0    3245.0
# 18        70.0  2609090.0    76634.0   35549.0   97089.0   51858.0    5478.0
# 19        47.0   145180.0     2639.0     520.0    4632.0    2933.0     510.0
# 20        37.0  1464478.0    68085.0   18981.0   22094.0   31434.0    6349.0
# 21        21.0   929951.0    90017.0   11676.0    2223.0   54353.0    4487.0
# 22        10.0   273619.0     5516.0    1401.0    1870.0    2663.0     300.0
# 23        13.0   932334.0    27381.0    8853.0   45299.0    9816.0     610.0
# 24        37.0   466655.0    10491.0   12050.0   36289.0    6756.0    1008.0
# 494        63.0    6676.0 2017-10-31 23:39:46.013093           3    35284.0
# 495        47.0  135519.0 2017-10-31 23:39:47.006876           3  1598903.0
# 496        41.0   48102.0 2017-10-31 23:39:48.028081           3   515157.0
# 497        47.0   14895.0 2017-10-31 23:39:49.020659           3   502355.0
# 498        50.0   58000.0 2017-10-31 23:39:49.998109           3   931780.0
# 499        50.0  185063.0 2017-10-31 23:39:50.991751           3  1669472.0
# 500        50.0  276747.0 2017-10-31 23:39:51.986841           3  1232716.0
#
#      user_activity_id  user_id  user_mental_state_id
# 0                   5        0                     5
# 1                   5        0                     5
# 2                   5        0                     5
# 3                   5        0                     5
# 4                   5        0                     5
# 5                   5        0                     5
# 6                   5        0                     5
# 7                   5        0                     5
# 8                   5        0                     5
# 9                   5        0                     5
# 10                  5        0                     5
# 11                  5        0                     5
# 12                  5        0                     5
# 13                  5        0                     5
# 14                  5        0                     5
# 15                  5        0                     5
# 16                  5        0                     5
# 17                  5        0                     5
# 18                  5        0                     5
# 19                  5        0                     5
# 20                  5        0                     5
# 21                  5        0                     5
# 22                  5        0                     5
# 23                  5        0                     5
# 24                  5        0                     5
# 25                  5        0                     5
# 26                  5        0                     5
# 27                  5        0                     5
# 28                  5        0                     5
# 29                  5        0                     5
# ..                ...      ...                   ...
# 471                 3        0                     2
# 472                 3        0                     2
# 473                 3        0                     2
# 474                 3        0                     2
# 475                 3        0                     2
# 476                 3        0                     2
# 477                 3        0                     2
# 478                 3        0                     2
# 479                 3        0                     2
# 480                 3        0                     2
# 481                 3        0                     2
# 482                 3        0                     2
# 483                 3        0                     2
# 484                 3        0                     2
# 485                 3        0                     2
# 486                 3        0                     2
# 487                 3        0                     2
# 488                 3        0                     2
# 489                 3        0                     2
# 490                 3        0                     2
# 491                 3        0                     2
# 492                 3        0                     2
# 493                 3        0                     2
# 494                 3        0                     2
# 495                 3        0                     2
# 496                 3        0                     2
# 497                 3        0                     2
# 498                 3        0                     2
# 499                 3        0                     2
# 500                 3        0                     2
#
# [2504 rows x 15 columns]

# %%
if __name__ == '__main__':
    mindwaveDataPointReader = MindwaveDataPointReader()
    mindwaveDataPointReader.start()
    if (mindwaveDataPointReader.isConnected()):    
        while(True):
            dataPoint = mindwaveDataPointReader.readNextDataPoint()
            if (not dataPoint.__class__ is RawDataPoint):
                print(dataPoint)
				
    else:
        print(textwrap.dedent("""\
            Exiting because the program could not connect
            to the Mindwave Mobile device.""").replace("\n", " "))
# Out:
# Discovered Mindwave Mobile...
# Meditation Level: 0
# Attention Level: 0
# EEG Powers:
#                 delta: 56
#                 theta: 2
#                 lowAlpha: 0
#                 highAlpha: 0
#                 lowBeta: 0
#                 highBeta: 1
#                 lowGamma: 0
#                 midGamma: 0
#
# Poor Signal Level: 25
# Meditation Level: 0
# Attention Level: 0
# EEG Powers:
#                 delta: 2372111
#                 theta: 255585
#                 lowAlpha: 32691
#                 highAlpha: 54146
#                 lowBeta: 68034
#                 highBeta: 76377
#                 lowGamma: 7438
#                 midGamma: 33045
#
# Poor Signal Level: 25
# Meditation Level: 0
# Attention Level: 0
# EEG Powers:
#                 delta: 1760724
#                 theta: 146555
#                 lowAlpha: 113680
#                 highAlpha: 126129
#                 lowBeta: 38410
#                 highBeta: 46443
#                 lowGamma: 18685
#                 midGamma: 146801
#
# Poor Signal Level: 25
# Meditation Level: 0
# Attention Level: 0
# EEG Powers:
#                 delta: 1289153
#                 theta: 177156
#                 lowAlpha: 55920
#                 highAlpha: 27438
#                 lowBeta: 43488
#                 highBeta: 56505
#                 lowGamma: 25740
#                 midGamma: 81620
#
# Poor Signal Level: 0
# Meditation Level: 0
# Attention Level: 0
# EEG Powers:
#                 delta: 1996215
#                 theta: 464546
#                 lowAlpha: 136648
#                 highAlpha: 61374
#                 lowBeta: 61898
#                 highBeta: 116829
#                 lowGamma: 37692
#                 midGamma: 40983
#
# Poor Signal Level: 0
# Meditation Level: 0
# Attention Level: 0
# EEG Powers:
#                 delta: 2262735
#                 theta: 466186
#                 lowAlpha: 28729
#                 highAlpha: 97054
#                 lowBeta: 31816
#                 highBeta: 26522
#                 lowGamma: 6403
#                 midGamma: 28815
#
# Poor Signal Level: 0
# Meditation Level: 53
# Attention Level: 35
# EEG Powers:
#                 delta: 991027
#                 theta: 320990
#                 lowAlpha: 378500
#                 highAlpha: 102147
#                 lowBeta: 30726
#                 highBeta: 42372
#                 lowGamma: 32761
#                 midGamma: 105442
#
# Poor Signal Level: 0
# Meditation Level: 53
# Attention Level: 35
# EEG Powers:
#                 delta: 2157171
#                 theta: 155982
#                 lowAlpha: 26848
#                 highAlpha: 61724
#                 lowBeta: 14342
#                 highBeta: 23570
#                 lowGamma: 15414
#                 midGamma: 9271
#
# Poor Signal Level: 26
# Meditation Level: 54
# Attention Level: 37
# EEG Powers:
#                 delta: 84765
#                 theta: 24242
#                 lowAlpha: 3313
#                 highAlpha: 16637
#                 lowBeta: 14064
#                 highBeta: 3469
#                 lowGamma: 654
#                 midGamma: 18555
#
# Poor Signal Level: 0
# Meditation Level: 47
# Attention Level: 48
# EEG Powers:
#                 delta: 145701
#                 theta: 76962
#                 lowAlpha: 3112
#                 highAlpha: 26226
#                 lowBeta: 29012
#                 highBeta: 18554
#                 lowGamma: 2380
#                 midGamma: 4479
#
# Poor Signal Level: 0
# Meditation Level: 54
# Attention Level: 41
# EEG Powers:
#                 delta: 499240
#                 theta: 31180
#                 lowAlpha: 26772
#                 highAlpha: 11624
#                 lowBeta: 11940
#                 highBeta: 3311
#                 lowGamma: 2027
#                 midGamma: 10056
#
# Poor Signal Level: 0
# Meditation Level: 37
# Attention Level: 50
# EEG Powers:
#                 delta: 16453
#                 theta: 130055
#                 lowAlpha: 40783
#                 highAlpha: 8080
#                 lowBeta: 10671
#                 highBeta: 15598
#                 lowGamma: 5335
#                 midGamma: 22722
#
# Poor Signal Level: 0
# Meditation Level: 43
# Attention Level: 51
# EEG Powers:
#                 delta: 82218
#                 theta: 15932
#                 lowAlpha: 13322
#                 highAlpha: 2681
#                 lowBeta: 4167
#                 highBeta: 2905
#                 lowGamma: 771
#                 midGamma: 6342
#
# Poor Signal Level: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-481714c9525e> in <module>()
#       5     if (mindwaveDataPointReader.isConnected()):
#       6         while(True):
# ----> 7             dataPoint = mindwaveDataPointReader.readNextDataPoint()
#       8             if (not dataPoint.__class__ is RawDataPoint):
#       9                 print(dataPoint)
#
# C:\Users\wasif\Anaconda3\lib\site-packages\mindwavemobile-0.200-py3.5.egg\mindwavemobile\MindwaveDataPointReader.py in readNextDataPoint(self)
#      19         #print("queue len:" +str(len(self._dataPointQueue)))
#      20         if (not self._moreDataPointsInQueue()):
# ---> 21             self._putNextDataPointsInQueue()
#      22         return self._getDataPointFromQueue()
#      23
#
# C:\Users\wasif\Anaconda3\lib\site-packages\mindwavemobile-0.200-py3.5.egg\mindwavemobile\MindwaveDataPointReader.py in _putNextDataPointsInQueue(self)
#      29
#      30     def _putNextDataPointsInQueue(self):
# ---> 31         dataPoints = self._readDataPointsFromOnePacket()
#      32         #print("data_points:" + "".join(dataPoints))
#      33         self._dataPointQueue.extend(dataPoints)
#
# C:\Users\wasif\Anaconda3\lib\site-packages\mindwavemobile-0.200-py3.5.egg\mindwavemobile\MindwaveDataPointReader.py in _readDataPointsFromOnePacket(self)
#      34
#      35     def _readDataPointsFromOnePacket(self):
# ---> 36         self._goToStartOfNextPacket()
#      37         payloadBytes, checkSum = self._readOnePacket()
#      38         if (not self._checkSumIsOk(payloadBytes, checkSum)):
#
# C:\Users\wasif\Anaconda3\lib\site-packages\mindwavemobile-0.200-py3.5.egg\mindwavemobile\MindwaveDataPointReader.py in _goToStartOfNextPacket(self)
#      46     def _goToStartOfNextPacket(self):
#      47         while(True):
# ---> 48             byte = self._mindwaveMobileRawReader.getByte()
#      49             if (byte == MindwaveMobileRawReader.START_OF_PACKET_BYTE):  # need two of these bytes at the start..
#      50                 byte = self._mindwaveMobileRawReader.getByte()
#
# C:\Users\wasif\Anaconda3\lib\site-packages\mindwavemobile-0.200-py3.5.egg\mindwavemobile\MindwaveMobileRawReader.py in getByte(self)
#      84
#      85     def getByte(self):
# ---> 86         self._ensureMoreBytesCanBeRead(100);
#      87         return self._getNextByte();
#      88
#
# C:\Users\wasif\Anaconda3\lib\site-packages\mindwavemobile-0.200-py3.5.egg\mindwavemobile\MindwaveMobileRawReader.py in _ensureMoreBytesCanBeRead(self, amountOfBytes)
#      89     def  _ensureMoreBytesCanBeRead(self, amountOfBytes):
#      90         if (self._bufferSize() <= self._bufferPosition + amountOfBytes):
# ---> 91             self._readMoreBytesIntoBuffer(amountOfBytes)
#      92
#      93     def _getNextByte(self):
#
# C:\Users\wasif\Anaconda3\lib\site-packages\mindwavemobile-0.200-py3.5.egg\mindwavemobile\MindwaveMobileRawReader.py in _readMoreBytesIntoBuffer(self, amountOfBytes)
#      55
#      56     def _readMoreBytesIntoBuffer(self, amountOfBytes):
# ---> 57         newBytes = self._readBytesFromMindwaveMobile(amountOfBytes)
#      58         self._buffer += newBytes
#      59         #print(self._buffer)
#
# C:\Users\wasif\Anaconda3\lib\site-packages\mindwavemobile-0.200-py3.5.egg\mindwavemobile\MindwaveMobileRawReader.py in _readBytesFromMindwaveMobile(self, amountOfBytes)
#      69             #for byte in missingBytes:
#      70                 #print(str(byte))
# ---> 71             added = self.mindwaveMobileSocket.recv(missingBytes)
#      72             #print(added)
#      73             #added = added.decode("ISO-8859-1")
#
# C:\Users\wasif\Anaconda3\lib\site-packages\pybluez-0.22-py3.5-win-amd64.egg\bluetooth\msbt.py in recv(self, numbytes)
#      82
#      83     def recv (self, numbytes):
# ---> 84         return bt.recv (self._sockfd, numbytes)
#      85
#      86     def close (self):
#
# KeyboardInterrupt:
